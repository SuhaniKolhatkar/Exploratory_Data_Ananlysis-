# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
list_1 = ['a','b','c','d']
labels = [1,2,3,4]

Ser_1 = pd.Series(data = list_1, index = labels)

# %%
Ser_1
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
arr_1 = np.array([1,2,3,4])
Ser_2 = pd.Series(data = arr_1)
Ser_2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
dict_1 = {
        "f_name" : "suhani",
        "s_name" : "kolhatkar",
        "age" : "19"
        }
Ser_3 = pd.Series(data = dict_1)
Ser_3
# Out:
# f_name       suhani
# s_name    kolhatkar
# age              19
# dtype: object

# %%
arr_2 = np.random.randint(10, 50, size = (2,3))
arr_2
# Out:
# array([[36, 20, 21],
#        [21, 34, 37]])

# %%
df_1 = pd.DataFrame(data = arr_2, index = ['suhani','pranoti'], columns = ['phy','chem','math'])
df_1
# Out:
#          phy  chem  math
# suhani    36    20    21
# pranoti   21    34    37

# %%
df_1[['math']]
# Out:
#          math
# suhani     21
# pranoti    37

# %%
df_1.loc[['suhani']]
# Out:
#         phy  chem  math
# suhani   36    20    21

# %%
df_1.iloc[[0]]
# Out:
#         phy  chem  math
# suhani   36    20    21

# %%
df_1.loc['suhani','math']
# Out:
# 21

# %%
df_1.loc[['suhani','pranoti'],['math','phy']]
df_1
# Out:
#          phy  chem  math
# suhani    36    20    21
# pranoti   21    34    37

# %%
df_1
# Out:
#          phy  chem  math
# suhani    36    20    21
# pranoti   21    34    37

# %%
df_1['Total'] = df_1['phy']+df_1['math']+df_1['chem']
df_1
# Out:
#          phy  chem  math  Total
# suhani    36    20    21     77
# pranoti   21    34    37     92

# %%
df_1.drop('Total', axis = 1, inplace = True)
df_1
# Out:
#          phy  chem  math
# suhani    36    20    21
# pranoti   21    34    37

# %%
dict_1 = {'phy': 30, 'math': 24, 'chem': 67}
dict_1
# Out:
# {'phy': 30, 'math': 24, 'chem': 67}

# %%
new_row = pd.Series(dict_1, name = 'sumedh')
new_row
# Out:
# phy     30
# math    24
# chem    67
# Name: sumedh, dtype: int64

# %%
df_1.drop('sumedh', axis = 0 , inplace)

# %%
df_1 = df_1.append(new_row)
df_1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7148\524248299.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_1 = df_1.append(new_row)
#          phy  chem  math
# suhani    36    20    21
# pranoti   21    34    37
# sumedh    30    67    24
# sumedh    30    67    24
# sumedh    30    67    24
# sumedh    30    67    24
# sumedh    30    67    24

# %%
df_1.drop('sumedh', axis = 0 , inplace = True)
df_1
# Out:
#          phy  chem  math
# suhani    36    20    21
# pranoti   21    34    37

# %% [markdown]
# ## Conditional Selectional of Data

# %%
arr_2 = np.random.randint(10,50, size=(2,3))

df_1 = pd.DataFrame(arr_2, ['A','B'], ['C','D','E'])
df_1
# Out:
#     C   D   E
# A  16  27  10
# B  20  45  22

# %%
#conditional formatting 
df_1.gt(10)
df_1 < 20
# Out:
#        C      D      E
# A   True  False   True
# B  False  False  False

# %%
df_1[df_1['C'] > 49]
# Out:
# Empty DataFrame
# Columns: [C, D, E]
# Index: []

# %% [markdown]
# ## File Output

# %%
cs_df = pd.read_csv('ComputerSales.csv')
cs_df
# Out:
#     Sale ID          Contact Sex  Age State Product ID Product Type  \
# 0         1      Paul Thomas   M   43    OH  M01-F0024      Desktop
# 1         2      Margo Simms   F   37    WV  GT13-0024      Desktop
# 2         3        Sam Stine   M   26    PA      I3670      Desktop
# 3         4       Moe Eggert   M   35    PA      I3593       Laptop
# 4         5      Jessica Elk   F   55    PA     15M-ED       Laptop
# 5         6  Sally Struthers   F   45    PA  GT13-0024      Desktop
# 6         7   Michelle Samms   F   46    OH    GA401IV       Laptop
# 7         8     Mick Roberts   M   23    OH    MY2J2LL       Tablet
# 8         9      Ed Klondike   M   52    OH     81TC00       Laptop
# 9        10       Phil Jones   M   56    WV  M01-F0024      Desktop
# 10       11       Rick James   M   49    PA    GA401IV       Laptop
# 11       12         Sue Etna   F   54    OH  GT13-0024      Desktop
# 12       13       Jason Case   M   57    PA     81TC00       Laptop
# ...

# %%
# !pip install ydata-profiling
# Out:
# ...
#      ------------------------------------ 357.8/357.8 kB 115.3 kB/s eta 0:00:00
# ...
#      ------------------------------------ 394.8/394.8 kB 880.0 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------ 296.5/296.5 kB 734.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 666.2/666.2 kB 1.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 102.7/102.7 kB 1.2 MB/s eta 0:00:00
# ...
#      ------------------------------------ 300.0/300.0 kB 842.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.7/4.7 MB 1.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.9/1.9 MB 140.1 kB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27092 sha256=acf040ab751524ce7f9635a2450ea80b1f1ad184a285996808f96a3fc61c673d
# ...

# %%
cs_df.to_csv('ComputerSalesBU01.csv')

# %%
pd.read_excel('Financial Sample.xlsx', 0)
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
pwd #present working directory
# Out:
# 'C:\\Users\\Admin\\Downloads\\Pandas'

# %%
#https://docs.google.com/spreadsheets/d/16vRPh_UmviA89NtzNxrK4Q5s8HOKCrUO3H86AHccBOo/edit?usp=sharing

# %%
sheet_id = '16vRPh_UmviA89NtzNxrK4Q5s8HOKCrUO3H86AHccBOo'
xls = pd.ExcelFile(f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=xlsx")

year_2019 = pd.read_excel(xls , '2019' , header = 1 )
year_2019
# Out:
#     2019-01-02 16:00:00.288000  52.29
# 0      2019-01-03 16:00:00.288  50.80
# 1      2019-01-04 16:00:00.288  53.54
# 2      2019-01-07 16:00:00.288  53.42
# 3      2019-01-08 16:00:00.288  53.81
# 4      2019-01-09 16:00:00.288  53.73
# ..                         ...    ...
# 245    2019-12-23 16:00:00.288  67.44
# 246    2019-12-24 13:00:00.288  67.18
# 247    2019-12-26 16:00:00.288  68.02
# 248    2019-12-27 16:00:00.288  67.59
# 249    2019-12-30 16:00:00.288  66.81
#
# [250 rows x 2 columns]

# %%
year_2019.describe()
# Out:
#             52.29
# count  250.000000
# mean    59.418680
# std      4.052371
# min     50.800000
# 25%     56.080000
# 50%     59.250000
# 75%     61.977500
# max     68.060000

# %%
cs_df.head()
# Out:
#    Sale ID      Contact Sex  Age State Product ID Product Type  Sale Price  \
# 0        1  Paul Thomas   M   43    OH  M01-F0024      Desktop      479.99
# 1        2  Margo Simms   F   37    WV  GT13-0024      Desktop     1249.99
# 2        3    Sam Stine   M   26    PA      I3670      Desktop      649.99
# 3        4   Moe Eggert   M   35    PA      I3593       Laptop      399.99
# 4        5  Jessica Elk   F   55    PA     15M-ED       Laptop      699.99
#
#    Profit     Lead     Month  Year
# 0  143.39  Website   January  2018
# 1  230.89  Flyer 4   January  2018
# 2  118.64  Website  February  2018
# 3   72.09  Website     March  2018
# 4   98.09  Flyer 4     March  2018

# %%
year_2019.tail(10)
# Out:
#     2019-01-02 16:00:00.288000  52.29
# 240    2019-12-16 16:00:00.288  68.06
# 241    2019-12-17 16:00:00.288  67.76
# 242    2019-12-18 16:00:00.288  67.63
# 243    2019-12-19 16:00:00.288  67.80
# 244    2019-12-20 16:00:00.288  67.48
# 245    2019-12-23 16:00:00.288  67.44
# 246    2019-12-24 13:00:00.288  67.18
# 247    2019-12-26 16:00:00.288  68.02
# 248    2019-12-27 16:00:00.288  67.59
# 249    2019-12-30 16:00:00.288  66.81
